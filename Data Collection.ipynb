# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os
from io import StringIO
import json
from IPython.display import display


import re

def extract_core_table_name(long_table_name):
    # Use regular expression to find the first occurrence of a numeric character
    match = re.search(r'\d', long_table_name)
    if match:
        index = match.start()
        # Extract the part before the year (first number)
        core_table_name = long_table_name[:index].rstrip('_')
        return core_table_name
    else:
        # Return the original name if no number is found, or adjust as needed
        return long_table_name


def save_to_json(df, league, season, table_name, filepath):
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = [' '.join(col).strip() for col in df.columns.values]

    data = df.to_dict(orient='records')

    content = {
        "league": league,
        "season": season,
        "table_name": table_name,
        "data": data
    }

    os.makedirs(os.path.dirname(filepath), exist_ok=True)

    with open(filepath, 'w') as f:
        json.dump(content, f, indent=4)

def get_tables_with_names(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    tables = soup.find_all('table')
    table_names = [caption.text.strip() for caption in soup.find_all('caption')]
    return tables, table_names

def parse_tables(url, league, season, directory):
    tables, table_names = get_tables_with_names(url)

    for i, (table, name) in enumerate(zip(tables, table_names)):
        long_table_name = name.replace(' ', '_').replace('/', '_')  # Normalize table name
        table_name = extract_core_table_name(long_table_name)

        # Check if this is a "versus" table based on the index
        if i % 2 == 1:
            table_name += "_versus"

        # Wrap the HTML content in a StringIO object
        html_content = StringIO(str(table))

        # Use read_html on the StringIO object
        df = pd.read_html(html_content)[0]  # Convert the table to a DataFrame

        # Define the JSON file path
        json_filepath = os.path.join(directory, f"{league}_{season}_{table_name}.json")

        # Save the DataFrame and its metadata as JSON
        save_to_json(df, league, season, table_name, json_filepath)

# %%
url = "https://fbref.com/en/comps/"
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
tables = soup.find_all('table')

# %% [markdown]
# Data Scraping Loop

# %%
def scrap_data(season_list,directory,league,num):
    for season in season_list:
        url = f"https://fbref.com/en/comps/{num}/{season}/{season}-{league}-Stats"
        print(url)
        parse_tables(url, league, season, directory)

# %%
season_list = ["2022-2023","2021-2022","2020-2021","2019-2020","2018-2019"]
directory = "data"
league = 'Bundesliga'
num = '20'

#scrap_data(season_list,directory,league,num)

# %% [markdown]
# # First Tier

# %%
league_num_list = [('Premier-League',9),('La-Liga',12),('Serie-A',11),('Bundesliga',20),('Ligue-1',13)]
for league,num in league_num_list:
    print(f"scraping data for {league}")
    scrap_data(season_list,directory,league,num)
# Out:
# scraping data for Premier-League
# https://fbref.com/en/comps/9/2022-2023/2022-2023-Premier-League-Stats
# https://fbref.com/en/comps/9/2021-2022/2021-2022-Premier-League-Stats
# https://fbref.com/en/comps/9/2020-2021/2020-2021-Premier-League-Stats
# https://fbref.com/en/comps/9/2019-2020/2019-2020-Premier-League-Stats
# https://fbref.com/en/comps/9/2018-2019/2018-2019-Premier-League-Stats
# scraping data for La-Liga
# https://fbref.com/en/comps/12/2022-2023/2022-2023-La-Liga-Stats
# https://fbref.com/en/comps/12/2021-2022/2021-2022-La-Liga-Stats
# https://fbref.com/en/comps/12/2020-2021/2020-2021-La-Liga-Stats
# https://fbref.com/en/comps/12/2019-2020/2019-2020-La-Liga-Stats
# https://fbref.com/en/comps/12/2018-2019/2018-2019-La-Liga-Stats
# scraping data for Serie-A
# https://fbref.com/en/comps/11/2022-2023/2022-2023-Serie-A-Stats
# https://fbref.com/en/comps/11/2021-2022/2021-2022-Serie-A-Stats
# https://fbref.com/en/comps/11/2020-2021/2020-2021-Serie-A-Stats
# https://fbref.com/en/comps/11/2019-2020/2019-2020-Serie-A-Stats
# https://fbref.com/en/comps/11/2018-2019/2018-2019-Serie-A-Stats
# scraping data for Bundesliga
# https://fbref.com/en/comps/20/2022-2023/2022-2023-Bundesliga-Stats
# https://fbref.com/en/comps/20/2021-2022/2021-2022-Bundesliga-Stats
# https://fbref.com/en/comps/20/2020-2021/2020-2021-Bundesliga-Stats
# https://fbref.com/en/comps/20/2019-2020/2019-2020-Bundesliga-Stats
# https://fbref.com/en/comps/20/2018-2019/2018-2019-Bundesliga-Stats
# scraping data for Ligue-1
# https://fbref.com/en/comps/13/2022-2023/2022-2023-Ligue-1-Stats
# https://fbref.com/en/comps/13/2021-2022/2021-2022-Ligue-1-Stats
# https://fbref.com/en/comps/13/2020-2021/2020-2021-Ligue-1-Stats
# https://fbref.com/en/comps/13/2019-2020/2019-2020-Ligue-1-Stats
# https://fbref.com/en/comps/13/2018-2019/2018-2019-Ligue-1-Stats

# %% [markdown]
# # Second Tier

# %%
league_num_list = [('Championship',10),('Major-League-Soccer',22),('Eredivisie',23),('Primeira-Liga',32),('Liga-MX',31),
                   ('Serie-A',24),('Segunda-Division',17),('Belgian-Pro-League',37),('2-Bundesliga',33),('Ligue-2',60),
                   ('Serie-B',18),('Primera-Division',21)]
for league,num in league_num_list:
    print(f"scraping data for {league}")
    scrap_data(season_list,directory,league,num)
# Out:
# scraping data for Championship
# https://fbref.com/en/comps/10/2022-2023/2022-2023-Championship-Stats
# https://fbref.com/en/comps/10/2021-2022/2021-2022-Championship-Stats
# https://fbref.com/en/comps/10/2020-2021/2020-2021-Championship-Stats
# https://fbref.com/en/comps/10/2019-2020/2019-2020-Championship-Stats
# https://fbref.com/en/comps/10/2018-2019/2018-2019-Championship-Stats
# scraping data for Major-League-Soccer
# https://fbref.com/en/comps/22/2022-2023/2022-2023-Major-League-Soccer-Stats
# https://fbref.com/en/comps/22/2021-2022/2021-2022-Major-League-Soccer-Stats
# https://fbref.com/en/comps/22/2020-2021/2020-2021-Major-League-Soccer-Stats
# https://fbref.com/en/comps/22/2019-2020/2019-2020-Major-League-Soccer-Stats
# https://fbref.com/en/comps/22/2018-2019/2018-2019-Major-League-Soccer-Stats
# scraping data for Eredivisie
# https://fbref.com/en/comps/23/2022-2023/2022-2023-Eredivisie-Stats
# https://fbref.com/en/comps/23/2021-2022/2021-2022-Eredivisie-Stats
# https://fbref.com/en/comps/23/2020-2021/2020-2021-Eredivisie-Stats
# https://fbref.com/en/comps/23/2019-2020/2019-2020-Eredivisie-Stats
# https://fbref.com/en/comps/23/2018-2019/2018-2019-Eredivisie-Stats
# scraping data for Primeira-Liga
# https://fbref.com/en/comps/32/2022-2023/2022-2023-Primeira-Liga-Stats
# https://fbref.com/en/comps/32/2021-2022/2021-2022-Primeira-Liga-Stats
# https://fbref.com/en/comps/32/2020-2021/2020-2021-Primeira-Liga-Stats
# https://fbref.com/en/comps/32/2019-2020/2019-2020-Primeira-Liga-Stats
# https://fbref.com/en/comps/32/2018-2019/2018-2019-Primeira-Liga-Stats
# scraping data for Liga-MX
# https://fbref.com/en/comps/31/2022-2023/2022-2023-Liga-MX-Stats
# https://fbref.com/en/comps/31/2021-2022/2021-2022-Liga-MX-Stats
# https://fbref.com/en/comps/31/2020-2021/2020-2021-Liga-MX-Stats
# https://fbref.com/en/comps/31/2019-2020/2019-2020-Liga-MX-Stats
# https://fbref.com/en/comps/31/2018-2019/2018-2019-Liga-MX-Stats
# scraping data for Serie-A
# https://fbref.com/en/comps/24/2022-2023/2022-2023-Serie-A-Stats
# https://fbref.com/en/comps/24/2021-2022/2021-2022-Serie-A-Stats
# https://fbref.com/en/comps/24/2020-2021/2020-2021-Serie-A-Stats
# https://fbref.com/en/comps/24/2019-2020/2019-2020-Serie-A-Stats
# https://fbref.com/en/comps/24/2018-2019/2018-2019-Serie-A-Stats
# scraping data for Segunda-Division
# https://fbref.com/en/comps/17/2022-2023/2022-2023-Segunda-Division-Stats
# https://fbref.com/en/comps/17/2021-2022/2021-2022-Segunda-Division-Stats
# https://fbref.com/en/comps/17/2020-2021/2020-2021-Segunda-Division-Stats
# https://fbref.com/en/comps/17/2019-2020/2019-2020-Segunda-Division-Stats
# https://fbref.com/en/comps/17/2018-2019/2018-2019-Segunda-Division-Stats
# scraping data for Belgian-Pro-League
# https://fbref.com/en/comps/37/2022-2023/2022-2023-Belgian-Pro-League-Stats
# https://fbref.com/en/comps/37/2021-2022/2021-2022-Belgian-Pro-League-Stats
# https://fbref.com/en/comps/37/2020-2021/2020-2021-Belgian-Pro-League-Stats
# https://fbref.com/en/comps/37/2019-2020/2019-2020-Belgian-Pro-League-Stats
# https://fbref.com/en/comps/37/2018-2019/2018-2019-Belgian-Pro-League-Stats
# scraping data for 2-Bundesliga
# https://fbref.com/en/comps/33/2022-2023/2022-2023-2-Bundesliga-Stats
# https://fbref.com/en/comps/33/2021-2022/2021-2022-2-Bundesliga-Stats
# https://fbref.com/en/comps/33/2020-2021/2020-2021-2-Bundesliga-Stats
# https://fbref.com/en/comps/33/2019-2020/2019-2020-2-Bundesliga-Stats
# https://fbref.com/en/comps/33/2018-2019/2018-2019-2-Bundesliga-Stats
# scraping data for Ligue-2
# https://fbref.com/en/comps/60/2022-2023/2022-2023-Ligue-2-Stats
# https://fbref.com/en/comps/60/2021-2022/2021-2022-Ligue-2-Stats
# https://fbref.com/en/comps/60/2020-2021/2020-2021-Ligue-2-Stats
# https://fbref.com/en/comps/60/2019-2020/2019-2020-Ligue-2-Stats
# https://fbref.com/en/comps/60/2018-2019/2018-2019-Ligue-2-Stats
# scraping data for Serie-B
# https://fbref.com/en/comps/18/2022-2023/2022-2023-Serie-B-Stats
# https://fbref.com/en/comps/18/2021-2022/2021-2022-Serie-B-Stats
# https://fbref.com/en/comps/18/2020-2021/2020-2021-Serie-B-Stats
# https://fbref.com/en/comps/18/2019-2020/2019-2020-Serie-B-Stats
# https://fbref.com/en/comps/18/2018-2019/2018-2019-Serie-B-Stats
# scraping data for Primera-Division
# https://fbref.com/en/comps/21/2022-2023/2022-2023-Primera-Division-Stats
# https://fbref.com/en/comps/21/2021-2022/2021-2022-Primera-Division-Stats
# https://fbref.com/en/comps/21/2020-2021/2020-2021-Primera-Division-Stats
# https://fbref.com/en/comps/21/2019-2020/2019-2020-Primera-Division-Stats
# https://fbref.com/en/comps/21/2018-2019/2018-2019-Primera-Division-Stats

# %% [markdown]
# # Female Data

# %%
directory = "female_data"
league_num_list = [('Womens-Super-League',189),('NWSL',182),('A-League-Women',196),('Division-1-Feminine',193),
                   ('Frauen-Bundesliga',183),('Serie-A',208)]
for league,num in league_num_list:
    print(f"scraping data for {league}")
    scrap_data(season_list,directory,league,num)
# Out:
# scraping data for Womens-Super-League
# https://fbref.com/en/comps/189/2022-2023/2022-2023-Womens-Super-League-Stats
# https://fbref.com/en/comps/189/2021-2022/2021-2022-Womens-Super-League-Stats
# https://fbref.com/en/comps/189/2020-2021/2020-2021-Womens-Super-League-Stats
# https://fbref.com/en/comps/189/2019-2020/2019-2020-Womens-Super-League-Stats
# https://fbref.com/en/comps/189/2018-2019/2018-2019-Womens-Super-League-Stats
# scraping data for NWSL
# https://fbref.com/en/comps/182/2022-2023/2022-2023-NWSL-Stats
# https://fbref.com/en/comps/182/2021-2022/2021-2022-NWSL-Stats
# https://fbref.com/en/comps/182/2020-2021/2020-2021-NWSL-Stats
# https://fbref.com/en/comps/182/2019-2020/2019-2020-NWSL-Stats
# https://fbref.com/en/comps/182/2018-2019/2018-2019-NWSL-Stats
# scraping data for Liga-F
# https://fbref.com/en/comps/230/2022-2023/2022-2023-Liga-F-Stats
# https://fbref.com/en/comps/230/2021-2022/2021-2022-Liga-F-Stats
# https://fbref.com/en/comps/230/2020-2021/2020-2021-Liga-F-Stats
# https://fbref.com/en/comps/230/2019-2020/2019-2020-Liga-F-Stats
# https://fbref.com/en/comps/230/2018-2019/2018-2019-Liga-F-Stats
# scraping data for A-League-Women
# https://fbref.com/en/comps/196/2022-2023/2022-2023-A-League-Women-Stats
# https://fbref.com/en/comps/196/2021-2022/2021-2022-A-League-Women-Stats
# https://fbref.com/en/comps/196/2020-2021/2020-2021-A-League-Women-Stats
# https://fbref.com/en/comps/196/2019-2020/2019-2020-A-League-Women-Stats
# https://fbref.com/en/comps/196/2018-2019/2018-2019-A-League-Women-Stats
# scraping data for Division-1-Feminine
# https://fbref.com/en/comps/193/2022-2023/2022-2023-Division-1-Feminine-Stats
# https://fbref.com/en/comps/193/2021-2022/2021-2022-Division-1-Feminine-Stats
# https://fbref.com/en/comps/193/2020-2021/2020-2021-Division-1-Feminine-Stats
# https://fbref.com/en/comps/193/2019-2020/2019-2020-Division-1-Feminine-Stats
# https://fbref.com/en/comps/193/2018-2019/2018-2019-Division-1-Feminine-Stats
# scraping data for Frauen-Bundesliga
# https://fbref.com/en/comps/183/2022-2023/2022-2023-Frauen-Bundesliga-Stats
# https://fbref.com/en/comps/183/2021-2022/2021-2022-Frauen-Bundesliga-Stats
# https://fbref.com/en/comps/183/2020-2021/2020-2021-Frauen-Bundesliga-Stats
# https://fbref.com/en/comps/183/2019-2020/2019-2020-Frauen-Bundesliga-Stats
# https://fbref.com/en/comps/183/2018-2019/2018-2019-Frauen-Bundesliga-Stats
# scraping data for Serie-A
# https://fbref.com/en/comps/208/2022-2023/2022-2023-Serie-A-Stats
# https://fbref.com/en/comps/208/2021-2022/2021-2022-Serie-A-Stats
# https://fbref.com/en/comps/208/2020-2021/2020-2021-Serie-A-Stats
# https://fbref.com/en/comps/208/2019-2020/2019-2020-Serie-A-Stats
# https://fbref.com/en/comps/208/2018-2019/2018-2019-Serie-A-Stats

# %%
url = f"https://fbref.com/en/comps/9/{league}-Stats"

# %%
season_list = ["2022-2023","2021-2022","2020-2021","2019-2020","2018-2019"]

# %%
for season in season_list:
    url = f"https://fbref.com/en/comps/9/{season}/{season}-Premier-League-Stats"
    print(url)
# Out:
# https://fbref.com/en/comps/9/2022-2023/2022-2023-Premier-League-Stats
# https://fbref.com/en/comps/9/2021-2022/2021-2022-Premier-League-Stats
# https://fbref.com/en/comps/9/2020-2021/2020-2021-Premier-League-Stats
# https://fbref.com/en/comps/9/2019-2020/2019-2020-Premier-League-Stats
# https://fbref.com/en/comps/9/2018-2019/2018-2019-Premier-League-Stats

# %%
151*24
# Out:
# 3624
